# %%
with open("./input.txt", "r") as f:
    lines = f.read().splitlines()

print(lines)
# Out:
# ['C Z', 'C Z', 'C Y', 'C Z', 'C Z', 'C Z', 'A X', 'A X', 'C X', 'C X', 'A Z', 'B X', 'A X', 'C Z', 'A Z', 'C Z', 'C Z', 'C Z', 'A Z', 'A X', 'C Z', 'C Z', 'A Y', 'A Y', 'A X', 'C Z', 'A Y', 'A Y', 'C Z', 'C Y', 'C Y', 'C Z', 'A X', 'A X', 'A Y', 'C Z', 'A Y', 'A Y', 'A X', 'A Z', 'C Z', 'A X', 'C X', 'A Y', 'B Y', 'B Y', 'C Z', 'A Z', 'B X', 'A Z', 'B Z', 'B Z', 'A Y', 'C Z', 'C Z', 'C X', 'B Z', 'C Z', 'A Y', 'C Z', 'A X', 'C X', 'A X', 'C Z', 'A Y', 'B X', 'A Y', 'C Z', 'B Y', 'C Z', 'C Z', 'A Y', 'A Y', 'A Y', 'C Z', 'B Y', 'A X', 'A Y', 'C Z', 'A Y', 'C Z', 'C Z', 'C Z', 'B X', 'A Y', 'B X', 'C Z', 'C Z', 'B Y', 'A X', 'B Z', 'C Z', 'A X', 'C Z', 'B Y', 'C Z', 'A Y', 'A Y', 'A Z', 'C Z', 'A Y', 'B Z', 'A Z', 'A Y', 'A X', 'A Y', 'A X', 'A Y', 'A X', 'C Z', 'A Y', 'B Z', 'B Y', 'A X', 'C Z', 'A X', 'B Z', 'A X', 'A Y', 'C Z', 'A Z', 'A X', 'C X', 'A Y', 'A X', 'A X', 'A X', 'B Y', 'B Y', 'A X', 'C Z', 'C Z', 'A Y', 'A X', 'A Z', 'C Z', 'B Y', 'B Z', 'C X', 'C Z', 'A X', 'A Y', 'C 
# ...

# %%
score = 0

for match in lines:
    a = match[0]
    b = match[-1]

    if b == "X":
        score += 1
        if a == "A":
        if a == "B":
        if a == "C":

    if b == "Y":
        score += 2
        if a == "A":
        if a == "B":
        if a == "C":

    if b == "Z":
        score += 3
        if a == "A":
        if a == "B":
        if a == "C":

print(rounds)
# Out:
# [['C', 'Z'], ['C', 'Z'], ['C', 'Y'], ['C', 'Z'], ['C', 'Z'], ['C', 'Z'], ['A', 'X'], ['A', 'X'], ['C', 'X'], ['C', 'X'], ['A', 'Z'], ['B', 'X'], ['A', 'X'], ['C', 'Z'], ['A', 'Z'], ['C', 'Z'], ['C', 'Z'], ['C', 'Z'], ['A', 'Z'], ['A', 'X'], ['C', 'Z'], ['C', 'Z'], ['A', 'Y'], ['A', 'Y'], ['A', 'X'], ['C', 'Z'], ['A', 'Y'], ['A', 'Y'], ['C', 'Z'], ['C', 'Y'], ['C', 'Y'], ['C', 'Z'], ['A', 'X'], ['A', 'X'], ['A', 'Y'], ['C', 'Z'], ['A', 'Y'], ['A', 'Y'], ['A', 'X'], ['A', 'Z'], ['C', 'Z'], ['A', 'X'], ['C', 'X'], ['A', 'Y'], ['B', 'Y'], ['B', 'Y'], ['C', 'Z'], ['A', 'Z'], ['B', 'X'], ['A', 'Z'], ['B', 'Z'], ['B', 'Z'], ['A', 'Y'], ['C', 'Z'], ['C', 'Z'], ['C', 'X'], ['B', 'Z'], ['C', 'Z'], ['A', 'Y'], ['C', 'Z'], ['A', 'X'], ['C', 'X'], ['A', 'X'], ['C', 'Z'], ['A', 'Y'], ['B', 'X'], ['A', 'Y'], ['C', 'Z'], ['B', 'Y'], ['C', 'Z'], ['C', 'Z'], ['A', 'Y'], ['A', 'Y'], ['A', 'Y'], ['C', 'Z'], ['B', 'Y'], ['A', 'X'], ['A', 'Y'], ['C', 'Z'], ['A', 'Y'], ['C', 'Z'], ['C', 'Z'], ['C', 'Z'], [
# ...
